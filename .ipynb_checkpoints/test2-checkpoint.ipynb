# %%
import numpy as np
import pandas as pd

# %%
path='./data/retirement_prediction.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
display(df)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#        department salary
# count       14999  14999
# unique         10      3
# top         sales    low
# freq         4140   7316

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(3,5))
plt.boxplot(df['satisfaction_level'], showmeans=True)
plt.title('satisfaction_level')
plt.show()

# %%
fig = plt.figure(figsize=(10, 12))

x1 = fig.add_subplot(2,3,1)
x2 = fig.add_subplot(2,3,2)
x3 = fig.add_subplot(2,3,3)
x4 = fig.add_subplot(2,3,4)
x5 = fig.add_subplot(2,3,5)
x6 = fig.add_subplot(2,3,6)

x1.boxplot(df['last_evaluation'], showmeans=True)
x2.boxplot(df['number_project'], showmeans=True)
x3.boxplot(df['average_montly_hours'], showmeans=True)
x4.boxplot(df['time_spend_company'], showmeans=True)
x5.boxplot(df['Work_accident'], showmeans=True)
x6.boxplot(df['promotion_last_5years'], showmeans=True)

plt.tight_layout()
plt.show()

# %%
# encoding map 생성
encoding_map = {'low':0,
                'medium':1,
                'high':2}

# salary 컬럼에 대해 mapping
df['salary'] = df['salary'].map(encoding_map)

# 변경 내용 확인
df['salary'].value_counts()
# Out:
# 0    7316
# 1    6446
# 2    1237
# Name: salary, dtype: int64

# %%
# Label Encoding 라이브러리
from sklearn.preprocessing import LabelEncoder

# 인코더 객체 생성
encoder = LabelEncoder()

# 인코딩 할 데이터 적합
encoder.fit(df['department'])

# 인코딩 변환(transform) 후 적용
df['department'] = encoder.transform(df['department'])

# 변환 확인
df['department'].value_counts()
# Out:
# 7    4140
# 9    2720
# 8    2229
# 0    1227
# 6     902
# 5     858
# 1     787
# 2     767
# 3     739
# 4     630
# Name: department, dtype: int64

# %%
# 독립변수(원인변수) == x_data
# 종속변수(결과변수) == y_data

# left 컬럼을 제외한 모든 데이터
x_data = df.drop('left', axis=1, inplace=False)

# left 컬럼 데이터
y_data = df['left']
