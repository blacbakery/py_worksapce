# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  seaborn 버전 확인
sns.__version__
# Out:
# '0.11.2'

# %% [markdown]
# ### 0.시각화 기본
# - https://matplotlib.org/3.1.1/gallery/index.html
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
1. figure (axes를 여러 개 포함 가능) 
2. axes (그림 그리는 실제 영역, plot 여러 개 포함 가능)

3. plot (그래프)

# %% [markdown]
# ### 1.선 그래프(Line plot)
# - plt.plot() 함수 사용
# - plt.plot([x], y, [fmt], [data]) 함수를 사용하여 x, y 축을 갖는 그래프 생성
#     - x, y : array-like or scalar
#     - fmt : str, optional, A format string, e.g. 'ro--' for red circles with dashed line
#     - 'ro--' : fmtcolor='red', marker='o', linestyle='dashed'
#     - data : indexable object, optional, DataFrame 같은 객체를 주면, x, y를 column 이름으로 줄 수 있음
# - plot 설명에서 색, marker 등에 대한 정보 확인
# - https://matplotlib.org/2.0.2/examples/color/named_colors.html
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# #### 1-1. 하나의 선 그리기
# - plt.plot(y) : x는 [0, 1, 2, ..] 자동생성
# - plt.plot(x, y) : x, y 둘 다 지정, 개수가 동일해야 함
# - plt.plt(x, y, fmt) : 선의 스타일 지정

# %%
# plot 그리기 실습
# y 축만 지정, x 축은 [0, 1, 2, 3...] 와 같이 자동으로 생성됨 
y = np.arange(5, 10)
plt.plot(y, 'bo--')  # (0, 5), (1, 6).... (4, 9)
plt.grid()
plt.show()

# %%
# x는 0 ~ 9, y = x**2 에 대한 그래프 그리기
x = np.arange(10)
y = x ** 2 # 0, 1, 4, 9 ...
plt.plot(x, y, 'go--')
plt.grid()
plt.show()

# %% [markdown]
#   ![image.png](data:image/png;base64,...)

# %%
# plot의 서식을 'ro' 빨간색 동그라미로 지정
# fmt : 'ro--' / color='red', marker='o', markersize=9, linestyle='dashed'
x = np.arange(10)
y = x ** 2
#plt.plot(x, y, 'ro--')
plt.plot(x, y, color='red', marker='o', markersize=9, linestyle='dashed')
plt.show()

# %% [markdown]
# #### 1-2. 여러 선 그리기
# - 하나의 plot 함수에 여러 선 정보 입력
#     - plt.plot(x, y, fmt, x2, y2, fmt2, ...)
# - plt.plot(x, y, fmt) 여러 번 사용
#     - plt.plot(x, y, fmt)
#     - plt.plot(x2, y2, fmt)

# %%
# plt.plot(x, y, fmt, x2, y2, fmt2, ...) 을 사용하여 여러 선 그리기
# y => x*2, x**2, x**3
# fmt : 'b-', 'gr--', 'go' 사용

x = np.arange(10)
plt.plot(x, x*2, 'bs-', x, x**2, 'r+-', x, x**3, 'go--')
plt.grid()
plt.show()

# %%
# plt.plot(x, y, fmt)을 여러 번 사용하여 여러 선 그리기
# y => x*2, x**2, x**3
# fmt : 'b-', 'gr--', 'go' 사용

x = np.arange(10)
plt.plot(x, x*2, 'b-')
plt.plot(x, x**2, 'r--')
plt.plot(x, x**3, 'go')
plt.grid()
plt.show()

# %% [markdown]
# #### 1-3. x,y 축 레이블 표시
# - plt.xlabel(str, fontsize) : x 축에 대한 레이블 표시
# - plt.ylabel(str, fontsize) : y 축에 대한 레이블 표시
# - plt.title(str, fontsize) : plot에 대한 제목

# %%
# X축  'money',  Y축 'time'  제목 : 'time for money'
x = np.arange(10)
plt.plot(x, x*2, 'b-', x, x**2, 'r--', x, x**3, 'go')
plt.title('time for money', fontsize=15)
plt.xlabel('money', fontsize=12)
plt.ylabel('time', fontsize=12)
plt.show()

# %% [markdown]
# #### 1-4. x, y 축 특정 영역만 표시
# - Limitation : 전체 데이터 중에 특정 영역만 표시
# - x, y 별도 설정
#     - plt.xlim(min, max)
#     - plt.ylim(min, max)
# - x, y 한번에 설정
#     - plt.axis([xmin, xmax, ymin, ymax])

# %%
# X축은 2.0 ~ 5.0, Y축은 5 ~ 20 영역만 표시함
x = np.arange(10)
y = x ** 2
plt.plot(x, y, 'ro--')
#plt.xlim(2, 5)
#plt.ylim(5, 20)
plt.axis([2, 5, 5, 20])
plt.grid()
plt.show()

# %% [markdown]
# #### 1-5. 범례 표시
# - Legend(범례), 범례 설정을 위해 그래프에 label이 있어야 함
# - 방법1
#         plt.plot(x, y, style, label='text')
#         plt.legend(loc='text')
#
# - 방법2
#         plt.plot에 label 생략
#         plt.legend(labels=[label1, label2 ...],loc='text')사용
#         (순서, 개수 동일)
#
# - loc : upper left, upper center, upper right, center left, center, center right, lower left, lower right, best, right 등

# %%
# 다음과 같은 결과로 범례가 표시되도록 
# plt.plot의 label, plt.legend의 loc을 지정해 본다
x = np.arange(10)
y = x ** 2
y2 = x*5 + 2
plt.plot(x, y, 'b-', label='first')
plt.plot(x, y2, 'r-', label='second')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### 1-6. 설명 화살표, 글 표시
# - plt.annotate(text, xy, xytext, arrowprops) 매우 다양한 형식이 있음!
#     - text : 표시할 문구
#     - xy : 화살표를 표시할 좌표, (x, y)
#     - xytext : 문구를 표시할 좌표, (x, y)
#     - arrowprops : 화살표 속성, dict 객체 지정 {'color':'blue'}
# - annotations : https://matplotlib.org/tutorials/text/annotations.html
#
# - plt.text(x, y, text)
#     - x, y : 문구 표시할 위치 좌표
#     - text : 표시할 문구
# - text : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html

# %%
# https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:TeX_%EB%AC%B8%EB%B2%95

# %%
x = np.arange(10)
y = x ** 2

plt.plot(x, y)

plt.annotate('here', xy=(4, 16),
             xytext=(5,20),
             arrowprops={'color':'green'})

plt.text(7, 70, '$y=x^2$')
plt.show()

# %% [markdown]
# ### 2.Subplot
# - 여러 plot을 나누어 표시
# - plt.subplot(row, col, idx)
#    - row, col : shape(행, 열)
#    - idx : 일련번호 1부터 시작
# - figure, axes = plt.subplots(row, col, **args)
#    - row, col : shape(행, 열)
#    - sharex = True (x축을 공유한다는 의미)
#    - constrained_layout = True (subplot 간 간격 확보 - 제목 달때)
# - figure : 1개 캔버스
# - axes : 캔버스 위에 그려지는 1개 그래프
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(2, 3, 1) (2, 3, 2) (2, 3, 3)
(2, 3, 4) (2, 3, 5) (2, 3, 6)

plt.subplot(2, 3, i)  # 행의 수, 열의 수

231 232 233
234 235 236

# %%
x = np.arange(10)
plt.subplot(2, 2, 1)
plt.plot(x, x**2)

plt.subplot(2, 2, 2)
plt.plot(x, x*5)

plt.subplot(223)
plt.plot(x, np.sin(x))

plt.subplot(224)
plt.plot(x, np.cos(x))

plt.show()

# %%
#6개
plt.subplot(3, 2, 1)
plt.plot([1,2,3], [10, 20, 30], 'ro--')
plt.subplot(3, 2, 4)
plt.plot([1,2,3], [10, 20, 30], 'bo--')
plt.subplot(3, 2, 6)
plt.plot([1,2,3], [10, 20, 30], 'go--')

# %% [markdown]
# ### 3.Scatter (산점도, 산포도, 분산 형 차트)
# - 산점도, 산포도, 분산 형 차트
# - 두 데이터간의 관계를 보기 위해 사용함
# - plt.scatter(x, y, s, c, alpha)
#    - s : scale
#    - c : color
#    - alpha : 투명도(0~1)
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html
# - line style은 링크 참고
#   - https://matplotlib.org/gallery/lines_bars_and_markers/linestyles.html#sphx-glr-gallery-lines-bars-and-markers-linestyles-py

# %%
x = np.arange(50)
y = x +np.random.randn(50)* 10
magnitude = np.random.randint(1, 100, 50)
category = np.random.randint(0, 5, 50)
plt.scatter(x, y, s=magnitude, c=category)

# %% [markdown]
# ### 4.bar 그래프 (범주형)
# - 여러 대상의 양적의 비교가 필요할 때 사용
# - 시간의 흐름에 따른 비교도 할 수 있지만, 변화의 흐름 보다는 변화의 크기에 집중이 필요할 때 사용함
# - plt.bar(x, y) : 수직바
# - plt.barh(x, y) : 수평바
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.barh.html

# %%
names = ['A', 'B', 'C']
values = [50, 30, 100]
# plt.subplot과 plt.bar를 사용하여 아래와 같은 그래프를 완성하세요.
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### 5.Figure Size(단위:inch)
# - Matplotlib에서 그래프(Axes, plot)는 Figure 객체내에 존재함
# - 그래프를 위한 새로운 Figure는 plt.figure() 함수를 통해 생성함
# - plt.figure(번호, figsize=크기, dpi=1인치당 픽셀)
# - 크기 단위 : 인치, 기본 1인치 = 72 픽셀 (dpi를 사용해 조절 가능)

# %%
Cell   - 텍스트를 포함한 사각형 (Cell은 여러 개의 Figure를 포함할 수 있음)
Figure - 전체 캔버스  (Figure는 여러 개의 Axes를 포함할 수 있음)
Axes - 1개 그래프 (Axes는 여러 개의 Plot을 포함할 수 있음)
Plot - 1개 선

# %%
x = np.arange(10)
y = x ** 2
# figure의 크기를 (20, 5)로 지정해 보세요.


plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 6.히스토그램 (연속형)
# - 변수가 하나인 단변수 데이터의 빈도수를 그래프로 표현(일변량 그래프)
# - 히스토그램을 그리기 위한 hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받음
# - 데이터 집계 결과를 반환
# - n, bins, patches = plt.hist(x, bins, range)
#    - x : 데이터
#    - bins : 계급
#    - range: 대상 범위, (min, max)
#    - n : 도수
#    - patches : 계급별 히스토그램 좌표와 높이
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html

# %%
import pandas as pd
np.random.seed(10)
x = 100 + 15 * np.random.randn(10000)
s, bins = pd.cut(x, bins=50, retbins=True)
s2 = s.value_counts()
df = pd.DataFrame(s2, columns=['count'])
df['rate'] = df['count']/ df['count'].sum()
df['density'] = df['rate']/(bins[1:]-bins[0:50])   #밀도 = 상대도수/계급구간길이
bins
# Out:
# array([ 45.56572113,  47.86935649,  50.06329493,  52.25723337,
#         54.45117181,  56.64511025,  58.83904868,  61.03298712,
#         63.22692556,  65.420864  ,  67.61480244,  69.80874087,
#         72.00267931,  74.19661775,  76.39055619,  78.58449463,
#         80.77843306,  82.9723715 ,  85.16630994,  87.36024838,
#         89.55418682,  91.74812525,  93.94206369,  96.13600213,
#         98.32994057, 100.52387901, 102.71781744, 104.91175588,
#        107.10569432, 109.29963276, 111.4935712 , 113.68750963,
#        115.88144807, 118.07538651, 120.26932495, 122.46326339,
#        124.65720182, 126.85114026, 129.0450787 , 131.23901714,
#        133.43295558, 135.62689401, 137.82083245, 140.01477089,
#        142.20870933, 144.40264777, 146.5965862 , 148.79052464,
#        150.98446308, 153.17840152, 155.37233996])

# %%
# x에 대해 50개 계급으로 나눈 히스토그램 그리기, 
# density=True 사용
np.random.seed(10)
x = 100 + 15 * np.random.randn(10000)
n, bins, patches = 
plt.grid()
plt.show()

# %%
bins
# Out:
# array([ 45.67541806,  47.86935649,  50.06329493,  52.25723337,
#         54.45117181,  56.64511025,  58.83904868,  61.03298712,
#         63.22692556,  65.420864  ,  67.61480244,  69.80874087,
#         72.00267931,  74.19661775,  76.39055619,  78.58449463,
#         80.77843306,  82.9723715 ,  85.16630994,  87.36024838,
#         89.55418682,  91.74812525,  93.94206369,  96.13600213,
#         98.32994057, 100.52387901, 102.71781744, 104.91175588,
#        107.10569432, 109.29963276, 111.4935712 , 113.68750963,
#        115.88144807, 118.07538651, 120.26932495, 122.46326339,
#        124.65720182, 126.85114026, 129.0450787 , 131.23901714,
#        133.43295558, 135.62689401, 137.82083245, 140.01477089,
#        142.20870933, 144.40264777, 146.5965862 , 148.79052464,
#        150.98446308, 153.17840152, 155.37233996])

# %%
# sns.histplot으로 그리면!
import seaborn as sns
np.random.seed(0)
x = 100 + 15 * np.random.randn(10000)
sns.histplot(x, color="blue", bins=50, kde=True, 
             stat="density", alpha=0.5, linewidth=0)
plt.grid()
plt.show()

# %% [markdown]
# ### 7.그래프 - 이미지
# - plt.imshow(arraylike or PIL)
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
from PIL import Image

img = Image.open('tkv.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !pip install opencv-python

# %%
import cv2

img = cv2.imread('tkv.jpg')
plt.imshow(img[:,:,::-1])
plt.axis('off')
plt.show()

# %% [markdown]
# ### 8.Seaborn를 이용한 시각화
# - matplotlib를 기반으로 하는 Python visualization라이브러리
# - attractive한 통계적 그래프를 제공하는 라이브러리
# - 공식사이트 : ```http://seaborn.pydata.org```
#     - boxplot
#     - swarmplot
#     - lmplot
#     - heatmap
#     - pairplot

# %%
# 라인플롯(Line plot) 그리기 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2 * np.sin(x+0.5)
y3 = 3 * np.sin(x+1.0)
y4 = 4 * np.sin(x+1.5)

plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %% [markdown]
# #### 스타일
# - seaborn을 import 하면 색상 등을 seaborn에서 지정한 기본 스타일로 바꿈
# - set 함수로 색상, tick 스타일 등 전반적인 플록 스타일을 seaborn 기본 스타일로 변경함
# - set_style 함수로 tick 스타일만 변경 가능
#    - darkgrid, whitegrid, dark, white, ticks 스타일 제공
# - set_color_codes 명령으로 기본 색상을 가리키는 문자열 변경

# %%
# set_style 연습 : dark 테마 적용
sns.set_style("dark")
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %%
# white 테마 적용
sns.set_style("whitegrid")
sns.despine(offset=10)
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.show()

# %% [markdown]
# #### Tips Data를 활용한 시각화 실습

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### 8-1. boxplot

# %%
# tips의 'total_bill' 의 분포를 boxplot으로 확인함 (x로 지정)
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))


plt.show()

# %%
# 특정 카테고리에 대한 값의 분포는 X,Y를 지정하여 확인 가능
# x, y, data 사용
plt.figure(figsize=(8, 6))


plt.show()

# %%
# hue 옵션을 통해 카테고리 별 데이터 시각화 가능
# palette 옵션을 통해 색상 지정 가능 ('Set3' 사용)
plt.figure(figsize=(8, 6))


plt.show()

# %% [markdown]
# #### 8-2.swarmplot
# - boxplot 보다 원본 데이터의 분포를 더 자세하게 확인할 때 사용

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(x="day", y="total_bill", data=tips, color=".5")
plt.show()

# %%
# boxplot + swarmplot
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
plt.show()

# %%
# Implot를 이용하여 회귀 그래프를 생성할 수 있음
sns.set_style("darkgrid")
plt.figure(figsize=(4, 3))
sns.lmplot(x="total_bill", y="tip", data=tips, height=7)
plt.show()

# %%
# hue 옵션을 통해 카테고리 별 적용 가능
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, height=7)
plt.show()

# %%
# palette 옵션을 통해 색상 적용 가능
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, palette="Set1",height=7)
plt.show()

# %% [markdown]
# #### 8-3 heatmap
# - 두 개의 카테고리 값에 의한 실수의 변화를 보고자 할 경우에 사용
# - 표출하고자 하는 데이터를 먼저 데이터 테이블 형태로 만들어야 함

# %%
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot("month", "year", "passengers")
flights.head(5)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(flights)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(flights, annot=True, fmt="d")
plt.show()

# %% [markdown]
# #### 8-4 pairplot
# - 데이터 분포 및 변수간 관계를 분석

# %%
sns.set(style="ticks")
iris = sns.load_dataset("iris")
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# pairplot을 이용하여 변수(컬럼)간 관계와 분포 확인 가능
#sns.set(style="ticks")
sns.pairplot(iris)
plt.show()

# %%
# hue 옵션을 이용하여 카테고리별 변수의 관계와 분포 확인 가능
sns.pairplot(iris, hue='species')
plt.show()

# %%
# vars 옵션을 이용하여 특정 변수만 지정 가능
sns.pairplot(iris, vars=['sepal_width', 'sepal_length'])
plt.show()

# %%
# x_vars, y_vars 옵션을 사용하여 해당 축의 특정 변수만 지정 가능
sns.pairplot(iris, x_vars=['sepal_width', 'sepal_length'],
            y_vars=['petal_width', 'petal_length'])
plt.show()

# %% [markdown]
# ## 9.Colab에서 한글 폰트 사용하기

# %%
###########폰트 라이브러리 불러오기#############
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib as mpl

# !sudo apt-get install -qq -y fonts-nanum

# %config InlineBackend.figure_format = 'retina'
sys_font=fm.findSystemFonts()
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rc('font', family=font_name)
mpl.font_manager._rebuild()
print('설치가 되었습니다.')
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# 설치가 되었습니다.

# %%
# 위의 코드 실행 후 colab 메뉴에서 '런타임' -> '런타임 다시 시작' 실행

# %%
####### 런타임 다시 시작 후 실행 #######
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
import seaborn as sns

plt.rcParams['font.family']='NanumGothic'  #폰트 설정
fm._rebuild()
sns.set(font="NanumGothic", rc={"axes.unicode_minus":False}, style='whitegrid')

# %% [markdown]
# ## 10.Pandas의 plot 기능
# - https://pandas.pydata.org/docs/user_guide/visualization.html

# %% [markdown]
# - df.plot(kind='xxx')
#    - kind : line, bar, pie, hist, kde, box, scatter, area 등
# - df.plot.xxx()
#    - xxx : kind의 종류를 적음
#    - 예) df.plot.bar()

# %% [markdown]
# - DataFrame, Series
# - ```DataFrame.plot(*args, **kwargs)```
# - ```Series.plot(*args, **kwargs)```
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.html
# - 주요 parameter
#   - x : DataFrame일 경우 사용됨
#   - y : DataFrame일 경우 사용됨
#   - kind : 'line', 'bar', 'barh', 'hist', 'box', 'kde', 'density', 'area', 'pie', 'scatter'(DataFrame only)
#   - layout: (row, column)의 튜플로 subplot의 shape 지정
#   - subplots : bool, default False, 각 컬럼을 subplots로 분리함
#   - sharex, sharey : subplots=True 인 경우 가용
#   - figsize : tuple, (width, height) in inches
#   - use_index : bool, default True (index를 x축의 ticks로 사용)
#   - title : 제목
#   - grid : bool, default None, 눈금선
#   - legend : bool
#   - style : stylelist or dict, The matplotlib line style per column.
#   - xticks : sequence (xticks로 사용할 값들)
#   - yticks : sequence (yticks로 사용할 값들)
#   - xlim, ylim : x, y에 대한 limitation
#   - xlabel, ylable : x, y축에 대한 이름
#   - rot : int, Rotation for ticks
#   - fontsize : int, xticks, yticks에 대한 폰트 크기
#   - stacked : bool, default False in line and bar plots, True in area plot
#   - sort_columns : bool, column names 정렬
#   - secondary_y : bool, 2중축

# %% [markdown]
# ### 10-01. Line plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 사용할 DataFrame 준비

# %%
import pandas as pd
data = {'국가': ['대한민국','미국', '중국', '호주'],
        '1분기': [60, 70, 80, 70],
        '2분기': [70, 72, 78, 75],
        '3분기': [80, 75, 80, 80],
        '4분기': [90, 80, 82, 85]}

df = pd.DataFrame(data) 
df.index = [3,4,5,6]
dfidx = df.set_index('국가')

# %%
df
# Out:
#      국가  1분기  2분기  3분기  4분기
# 3  대한민국   60   70   80   90
# 4    미국   70   72   75   80
# 5    중국   80   78   80   82
# 6    호주   70   75   80   85

# %%
dfidx
# Out:
#       1분기  2분기  3분기  4분기
# 국가
# 대한민국   60   70   80   90
# 미국     70   72   75   80
# 중국     80   78   80   82
# 호주     70   75   80   85

# %% [markdown]
# #### x, y축, style 지정하기

# %%
# [1] 선그래프 - x, y 축을 지정한다 
# (x축 : '국가', y축 : '1분기', style : 'ro-')
df.plot.line(x='국가', y='1분기', style=['ro-'])
plt.show()

# %%
# [2] 선그래프 - x축과 복수 개의 y축을 지정한다
# (x축 : '국가', y축 : ['1분기', '2분기', '3분기'],
#  style : ['ro-', 'bs--', 'go-'])
df.plot.line(x='국가', y=['1분기', '2분기', '3분기'], 
             style=['ro-', 'bs--', 'go-'])
plt.show()

# %%
# [3] 선그래프 - index를 x축으로 사용하고, y축을 지정하는 경우
# dfidx 를 사용하고, x축 생략, y, style 지정
print(dfidx.index)
dfidx.plot.line(y=['1분기', '2분기', '3분기'],
                style=['ro-', 'bs--', 'go-'])
plt.show()
# Out:
# Index(['대한민국', '미국', '중국', '호주'], dtype='object', name='국가')

# %%
# [4] DataFrame의 모든 숫자형 컬럼에 대해 선 그래프를 그림
# use_index=True가 기본값 이므로 x축 지정이 없을 때 x축은 index가 사용됨
# use_index=False를 사용하면 x축은 0, 1, 2, 3, ...이 사용됨
# 숫자인 경우 표시되는 눈금을 xticks를 사용해 할 수 있음
# use_index=False, xticks=[0,1,2,3]
df.plot.line() 
dfidx.plot.line() 
plt.show()

# %%
# [5] DataFrame에서 행/열 바꾸기  (DataFrame.T)
dfT = dfidx.T
dfT['합계'] = dfT.loc[:, '대한민국':'호주'].sum(axis=1)
dfT
# Out:
# 국가   대한민국  미국  중국  호주   합계
# 1분기    60  70  80  70  280
# 2분기    70  72  78  75  295
# 3분기    80  75  80  80  315
# 4분기    90  80  82  85  337

# %%
# [6] dfT를 사용하여 선그래프 그리기
# x축은 index, y축은 다른 모든 컬럼을 사용함
dfT.plot.line(xlabel='')
plt.show()

# %%
# [7] dfT를 사용하여 선그래프 그리기
# x축 생략, y축은 ['대한민국', '미국', '중국', '호주']를 사용함
dfT.plot.line(y=['대한민국', '미국', '중국', '호주'], xlabel='')
plt.show()

# %%
print(dfidx.index, dfT.index, sep='\n')
# Out:
# Index(['대한민국', '미국', '중국', '호주'], dtype='object', name='국가')
# Index(['1분기', '2분기', '3분기', '4분기'], dtype='object')

# %%
dfT
# Out:
# 국가   대한민국  미국  중국  호주   합계
# 1분기    60  70  80  70  280
# 2분기    70  72  78  75  295
# 3분기    80  75  80  80  315
# 4분기    90  80  82  85  337

# %% [markdown]
# #### 2중축 차트

# %%
# [8] 2중축 차트 - 합계를 두 번째 y축으로 지정함
# 기본축 차트 : x축 생략, y축 : ['대한민국', '미국', '중국', '호주']
# 보조축 차트 : y축 : '합계', ax를 기본축으로 지정, color:'red', secondary_y=True
ax1 = dfT.plot.line(y=['대한민국', '미국', '중국', '호주'],
                    style={'대한민국':'bo--', '미국':'gs--'}) 
ax2 = dfT.plot.line(y='합계', ax=ax1, color='red', secondary_y=True) 

# ax.set_ylabel(레이블)을 사용해 y축 레이블을 설정함
ax1.set_ylabel('판매량') 
ax2.set_ylabel('합계')
plt.show()

# %% [markdown]
# ### 10-02. Bar plot

# %%
df
# Out:
#      국가  1분기  2분기  3분기  4분기
# 3  대한민국   60   70   80   90
# 4    미국   70   72   75   80
# 5    중국   80   78   80   82
# 6    호주   70   75   80   85

# %%
# [9] 바(bar)그래프 - x축을 '국가', y축을 '1분기'로 사용
# rot=0, xlabel='', legend=False를 사용하여 
# label 표시 변경, 불필요한 내용 제거
df.plot.bar(x='국가', y='1분기', rot=0, xlabel='', legend=False)
plt.show()

# %% [markdown]
# #### xlabel, rot, fontsize 사용하기

# %%
# [10] 바(bar)그래프- 국가별 1~4분기 매출
# x축: '국가', y축 : ['1분기', '2분기', '3분기', '4분기']
# xlabel, rot, fontsize 사용하기
df.plot.bar(x='국가', y=['1분기', '2분기', '3분기', '4분기'],
            xlabel='', rot=0, fontsize=14)
plt.show()

# %%
dfT.index.name = '분기'
dfT
# Out:
# 국가   대한민국  미국  중국  호주   합계
# 분기
# 1분기    60  70  80  70  280
# 2분기    70  72  78  75  295
# 3분기    80  75  80  80  315
# 4분기    90  80  82  85  337

# %% [markdown]
# #### ylim 사용

# %%
# [10] 바(bar)그래프- 분기별 국가들의 매출
# x축: '분기', y축 : ['대한민국', '미국', '중국', '호주']
# ylim 사용하여 범례 및 데이터 표시 ylim=(50, 100)
dfT.plot.bar(y=['대한민국', '미국', '중국', '호주'], 
             rot=0, fontsize=14, ylim=(50, 110))
plt.show()

# %% [markdown]
# #### Stacked Bar 그래프

# %%
# [12] Stacked Bar그래프 - 분기별 국가들의 매출
# stacked=True의 사용으로 쌓인 형태로 표시
dfT.plot.bar(y=['대한민국', '미국', '중국', '호주'], 
             rot=0, fontsize=14, ylim=(0, 600), stacked=True)
plt.show()

# %% [markdown]
# ### 10-03. Pie 그래프
# - 범례 위치 : https://stackoverflow.com/questions/43272206/python-legend-overlaps-with-the-pie-chart

# %%
dfT
# Out:
# 국가   대한민국  미국  중국  호주   합계
# 분기
# 1분기    60  70  80  70  280
# 2분기    70  72  78  75  295
# 3분기    80  75  80  80  315
# 4분기    90  80  82  85  337

# %%
s = dfT['대한민국']
s
# Out:
# 분기
# 1분기    60
# 2분기    70
# 3분기    80
# 4분기    90
# Name: 대한민국, dtype: int64

# %%
# [13] Pie 그래프 - Series 사용 
# autopct 사용, ylabel 제거
s.plot.pie(autopct='%.2f%%', ylabel='')
plt.show()

# %% [markdown]
# ### 10-04. 히스토그램(histogram)

# %%
# 데이터 준비하기
import seaborn as sns
iris = sns.load_dataset("iris")  # 붓꽂 데이터
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# [14] 특정 컬럼에 대해 히스토그램 그리기
# y축 : sepal_length, bins : 50
iris.plot.hist(y='sepal_length', bins=50)
plt.show()

# %%
# [15] seaborn으로 특정 컬럼에 대해 범주별 히스토그램 그리기
# data : iris, x축 : 'sepal_length', hue : 'species', bins : 50, alpha:0.5
sns.histplot(data=iris, x='sepal_length', hue='species', 
             bins=50, alpha=0.5)
plt.show()

# %%
# [16] 컬럼별 히스토그램 그리기
# bins : 50, layout : (2,2), subplots=True, figsize=(8, 4)
iris.plot.hist(bins=50, layout=(2,2), subplots=True, figsize=(8, 4))
plt.show()

# %% [markdown]
# ### 10-05. Box plot

# %%
# 붓꽂 데이터 불러오기
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
# [17] iris 데이터에 대한 Box plot 그리기
iris.plot.box()
#plt.show()

# %%
# [18] iris 데이터에 대한 Box plot 그리기
# subplots로 열 별 출력, figsize=(8, 4) 사용
iris.plot(kind='box', subplots=True, figsize=(8,4))
plt.tight_layout()
plt.show()

# %%
## 고생 많으셨습니다!
